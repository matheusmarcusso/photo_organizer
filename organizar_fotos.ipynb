# %%
import os
import shutil
from datetime import datetime
from PIL import Image

# %%
def get_file_date(file_path):
    file_date = None
    if os.path.exists(file_path):
        file_stats = os.stat(file_path)
        mtime = file_stats.st_mtime
        ctime = file_stats.st_ctime
        file_date = datetime.fromtimestamp(min(mtime, ctime))
    else:
        print(f"Erro: o arquivo {file_path} não existe")
    return file_date

def get_image_date(file_path):
    image_date = None
    try:
        with Image.open(file_path) as img:
            exif_data = img._getexif()
            if exif_data:
                date_taken = exif_data.get(36867)
                if date_taken:
                    image_date = datetime.strptime(date_taken, '%Y:%m:%d %H:%M:%S')
    except (AttributeError, OSError):
        pass
    return image_date

def move_files(source_dir, dest_dir):
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tif', '.tiff']
    video_extensions = ['.avi', '.mp4', '.mov', '.mkv']
    whatsapp_folder_name = 'Whatsapp'
    
    for root, dirs, files in os.walk(source_dir):
        for file in files:
            filename, extension = os.path.splitext(file)
            if extension.lower() not in image_extensions + video_extensions:
                continue

            src_file = os.path.join(root, file)
            file_date = None

            image_date = get_image_date(src_file)
            if image_date:
                file_date = image_date
            else:
                file_date = get_file_date(src_file)

            if not file_date:
                print(f"Erro: não foi possível determinar a data para o arquivo {src_file}")
                continue

            year = file_date.strftime('%Y')
            dest_folder = os.path.join(dest_dir, year)
            if not os.path.exists(dest_folder):
                os.makedirs(dest_folder)

            if 'WA' in filename:
                whatsapp_folder = os.path.join(dest_dir, whatsapp_folder_name, year)
                if not os.path.exists(whatsapp_folder):
                    os.makedirs(whatsapp_folder)
                dest_file = os.path.join(whatsapp_folder, file)
            else:
                dest_file = os.path.join(dest_folder, file)

            if os.path.exists(dest_file):
                duplicate_folder = os.path.join(dest_dir, 'duplicadas', year)
                if not os.path.exists(duplicate_folder):
                    os.makedirs(duplicate_folder)

                i = 1
                while True:
                    new_file_name = f"{filename}_{i}{extension}"
                    new_dest_file = os.path.join(duplicate_folder, new_file_name)
                    if not os.path.exists(new_dest_file):
                        shutil.move(src_file, new_dest_file)
                        print(f"O arquivo {src_file} foi movido para {new_dest_file} (data: {file_date})")
                        break
                    i += 1

            else:
                shutil.move(src_file, dest_file)
                print(f"O arquivo {src_file} foi movido para {dest_file} (data: {file_date})")

# %%
if __name__ == '__main__':
    source_dir = 'C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017'
    dest_dir = 'C:/Users/mathe/OneDrive/0 - Organizadas/Por ano'
    move_files(source_dir, dest_dir)
# Out:
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170101_115600.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170101_115600_1.jpg (data: 2017-01-01 11:55:59)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170101_115605.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170101_115605_1.jpg (data: 2017-01-01 11:56:05)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170101_115624.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170101_115624_1.jpg (data: 2017-01-01 11:56:24)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170101_124147.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170101_124147_1.jpg (data: 2017-01-01 12:41:47)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170101_124154.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170101_124154_1.jpg (data: 2017-01-01 12:41:54)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170101_124200.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170101_124200_1.jpg (data: 2017-01-01 12:42:00)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170101_124205.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170101_124205_1.jpg (data: 2017-01-01 12:42:04)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170102_125701.mp4 foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170102_125701_1.mp4 (data: 2017-01-02 11:57:26)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170102_193139.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170102_193139_1.jpg (data: 2017-01-02 19:31:39)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170104_122248.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170104_122248_1.jpg (data: 2017-01-04 12:22:47)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170104_122331.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170104_122331_1.jpg (data: 2017-01-04 12:23:31)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170104_122334.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170104_122334_1.jpg (data: 2017-01-04 12:23:34)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170104_122343.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170104_122343_1.jpg (data: 2017-01-04 12:23:42)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170104_152146.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170104_152146_1.jpg (data: 2017-01-04 15:21:46)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170104_152148.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170104_152148_1.jpg (data: 2017-01-04 15:21:48)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170104_152151.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170104_152151_1.jpg (data: 2017-01-04 15:21:50)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170112_122950.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170112_122950_1.jpg (data: 2017-01-12 12:29:49)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170114_190524.mp4 foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170114_190524_1.mp4 (data: 2017-01-14 18:05:26)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170114_190556.mp4 foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170114_190556_1.mp4 (data: 2017-01-14 18:07:06)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170115_163704.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170115_163704_1.jpg (data: 2017-01-15 16:37:04)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170115_174315.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170115_174315_1.jpg (data: 2017-01-15 17:43:15)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170117_184349.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170117_184349_1.jpg (data: 2017-01-17 18:43:49)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170118_192821.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170118_192821_1.jpg (data: 2017-01-18 19:28:21)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170119_093451.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170119_093451_1.jpg (data: 2017-01-19 09:34:51)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170126_222731.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170126_222731_1.jpg (data: 2017-01-26 22:27:30)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170126_222732.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170126_222732_1.jpg (data: 2017-01-26 22:27:32)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170126_223604.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170126_223604_1.jpg (data: 2017-01-26 22:36:04)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170126_223607.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170126_223607_1.jpg (data: 2017-01-26 22:36:07)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170126_232622.mp4 foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170126_232622_1.mp4 (data: 2017-01-26 22:26:58)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170128_153807.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170128_153807_1.jpg (data: 2017-01-28 15:38:07)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170128_153810.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170128_153810_1.jpg (data: 2017-01-28 15:38:10)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_010858.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_010858_1.jpg (data: 2017-01-29 01:08:58)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_010900.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_010900_1.jpg (data: 2017-01-29 01:09:00)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_015510.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_015510_1.jpg (data: 2017-01-29 01:55:10)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_021516.mp4 foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_021516_1.mp4 (data: 2017-01-29 01:15:30)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_022158.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_022158_1.jpg (data: 2017-01-29 02:21:58)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_022159.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_022159_1.jpg (data: 2017-01-29 02:21:59)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_022201.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_022201_1.jpg (data: 2017-01-29 02:22:01)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_022203.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_022203_1.jpg (data: 2017-01-29 02:22:02)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_031639.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_031639_1.jpg (data: 2017-01-29 03:16:39)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_031641.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_031641_1.jpg (data: 2017-01-29 03:16:41)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_045210.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_045210_1.jpg (data: 2017-01-29 04:52:10)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170129_045218.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170129_045218_1.jpg (data: 2017-01-29 04:52:17)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170201_120714.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170201_120714_1.jpg (data: 2017-02-01 12:07:14)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170201_120719.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170201_120719_1.jpg (data: 2017-02-01 12:07:18)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170201_213941.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170201_213941_1.jpg (data: 2017-02-01 21:39:41)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170204_115538.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170204_115538_1.jpg (data: 2017-02-04 11:55:38)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170222_094650.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170222_094650_1.jpg (data: 2017-02-22 09:46:50)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170222_121122.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170222_121122_1.jpg (data: 2017-02-22 12:11:22)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170222_121124.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170222_121124_1.jpg (data: 2017-02-22 12:11:23)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170223_072329.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170223_072329_1.jpg (data: 2017-02-23 07:23:28)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170223_072331.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170223_072331_1.jpg (data: 2017-02-23 07:23:31)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170224_014745.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170224_014745_1.jpg (data: 2017-02-24 01:47:44)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170224_014752.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170224_014752_1.jpg (data: 2017-02-24 01:47:51)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170224_014811.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170224_014811_1.jpg (data: 2017-02-24 01:48:11)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170224_014827.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170224_014827_1.jpg (data: 2017-02-24 01:48:26)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170224_014844.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170224_014844_1.jpg (data: 2017-02-24 01:48:43)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\20170224_014853.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\20170224_014853_1.jpg (data: 2017-02-24 01:48:52)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\61.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\61_1.jpg (data: 2017-04-12 01:45:37)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\aee67f7386efad6757d61b0af6c5a934.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\aee67f7386efad6757d61b0af6c5a934_1.jpg (data: 2017-03-18 12:31:12)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\agenda.png foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\agenda_1.png (data: 2017-10-27 15:55:10)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\banco.png foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\banco_1.png (data: 2017-10-30 15:08:46)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\brasil.png foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\brasil_1.png (data: 2017-10-30 15:12:24)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\chapéu graduação.png foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\chapéu graduação_1.png (data: 2017-10-27 15:48:28)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\download.png foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\download_1.png (data: 2017-09-12 00:08:28)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\fabrica.png foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\fabrica_1.png (data: 2017-10-30 15:04:54)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\FB_IMG_1484316532124.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\FB_IMG_1484316532124_1.jpg (data: 2017-01-13 11:08:52)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\FB_IMG_1487343252999.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\FB_IMG_1487343252999_1.jpg (data: 2017-02-17 11:54:14)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\FB_IMG_1487372092678.jpg foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\FB_IMG_1487372092678_1.jpg (data: 2017-02-17 19:54:52)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\fileShare.png foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\fileShare_1.png (data: 2017-11-28 13:50:11)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0053226.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0053226_2.JPG (data: 2017-08-04 09:42:52)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0053227.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0053227_2.JPG (data: 2017-08-04 09:42:54)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0053228.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0053228_2.JPG (data: 2017-08-04 09:42:56)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0053229.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0053229_2.JPG (data: 2017-08-04 09:42:58)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0053230.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0053230_2.JPG (data: 2017-08-04 09:43:00)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0053231.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0053231_2.JPG (data: 2017-08-04 09:43:02)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0053232.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0053232_2.JPG (data: 2017-08-04 09:43:04)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0063233.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0063233_2.JPG (data: 2017-08-04 09:44:54)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0063234.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0063234_2.JPG (data: 2017-08-04 09:44:56)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0063235.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0063235_2.JPG (data: 2017-08-04 09:44:58)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0063236.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0063236_2.JPG (data: 2017-08-04 09:45:00)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0063237.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0063237_2.JPG (data: 2017-08-04 09:45:02)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0063238.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0063238_2.JPG (data: 2017-08-04 09:45:04)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0063239.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0063239_2.JPG (data: 2017-08-04 09:45:06)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0063240.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0063240_2.JPG (data: 2017-08-04 09:45:08)
# O arquivo C:/Users/mathe/OneDrive/0 - Organizadas/Por ano/2017\G0063241.JPG foi movido para C:/Users/mathe/OneDrive/0 - Organizadas/Por ano\duplicadas\2017\G0063241_2.JPG (data: 2017-08-04 09:45:10)
